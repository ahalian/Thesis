# %%
import pandas as pd

# Import classifier and create object
from ethnos_classifier import EthnosClassifier

clf = EthnosClassifier()
# Out:
# c:\Users\Robert_Beta\miniforge3\envs\epp\Lib\site-packages\sklearn\base.py:440: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.5.2 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Robert_Beta\miniforge3\envs\epp\Lib\site-packages\sklearn\base.py:440: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.5.2 when using version 1.7.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
# Predict classes for "example.csv" table and save results to "example_pred.csv"
clf.predict('../data/names.csv', 'names_pred.csv')
# Out:
# c:\Users\Robert_Beta\.vscode\projects\Thesis\classifier\ethnos_classifier.py:65: UserWarning: Warning: Some names in your data contain characters different from russian letters, "-" character or space. Results for this names will be "INVALID" or 0.0 for probabilities
#   warnings.warn(

# %%
df_eth = pd.read_csv('names_pred.csv')

# %%
df_eth["agr_ethnos"].value_counts()
# Out:
# agr_ethnos
# BelRusUkr        97384
# BashTat           8723
# CheDagIng         2976
# KazKyr            1688
# KabAdKarBalOs     1664
# Buryat            1411
# Tuvan             1134
# Jewish            1034
# TajUzb            1024
# Moldovan           620
# Armenian           569
# Azerbaijani        394
# Kalmyk             227
# Georgian           190
# Yakut               91
# INVALID             25
# Name: count, dtype: int64
